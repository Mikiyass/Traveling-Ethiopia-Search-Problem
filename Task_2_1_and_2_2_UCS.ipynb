# %%
# --- TASK 2.1: Weighted Data Structure (Adjacency List with Costs) ---
# Weights taken from Figure 2
ethiopia_weighted_graph = {
    "Addis Ababa": {"Ambo": 5, "Adama": 3, "Debre Birhan": 5},
    "Adama": {"Addis Ababa": 3, "Batu": 4, "Assella": 4, "Matahara": 3},
    "Adigrat": {"Mekelle": 4, "Asmera": 6},
    "Adwa": {"Axum": 1, "Mekelle": 7, "Shire": 8},
    "Alamata": {"Woldia": 3, "Mekelle": 5, "Sekota": 6},
    "Ambo": {"Addis Ababa": 5, "Nekemte": 9, "Wolkite": 6},
    "Arba Minch": {"Wolaita Sodo": 4, "Konso": 4},
    "Asmera": {"Adigrat": 6},
    "Assella": {"Adama": 4, "Dodolla": 15},
    "Assosa": {"Gimbi": 8},
    "Awash": {"Matahara": 1, "Chiro": 4, "Fanti Rasu": 7},
    "Azezo": {"Gondar": 1, "Metema": 7, "Bahir Dar": 3},
    "Babile": {"Harar": 2, "Jijiga": 3},
    "Bahir Dar": {"Debre Markos": 11, "Azezo": 3, "Metema": 7, "Injibara": 4},
    "Bale": {"Dodolla": 13, "Goba": 18, "Sof Oumer": 23},
    "Batu": {"Adama": 4, "Shashamene": 3, "Buta Jirra": 2},
    "Bedelle": {"Nekemte": 9, "Gore": 6, "Jimma": 7},
    "Bonga": {"Jimma": 4, "Tepi": 8, "Dawro": 10},
    "Bule Hora": {"Dilla": 4, "Yabello": 3},
    "Buta Jirra": {"Batu": 2, "Worabe": 2},
    "Chiro": {"Awash": 4, "Dire Dawa": 8},
    "Dawro": {"Bonga": 10, "Arba Minch": 10},
    "Dega Habur": {"Jijiga": 5, "Kebri Dehar": 6},
    "Debark": {"Gondar": 4, "Shire": 12},
    "Debre Birhan": {"Addis Ababa": 5, "Debre Sina": 2},
    "Debre Markos": {"Finote Selam": 3, "Bahir Dar": 11},
    "Debre Sina": {"Debre Birhan": 2, "Kemise": 6, "Debre Markos": 17},
    "Debre Tabor": {"Lalibela": 8, "Gondar": 6},
    "Dembi Dollo": {"Gimbi": 6, "Gambela": 4},
    "Dessia (Dessie)": {"Kemise": 4, "Woldia": 6},
    "Dilla": {"Hawassa": 3, "Bule Hora": 4},
    "Dire Dawa": {"Harar": 4, "Chiro": 8},
    "Dodolla": {"Shashamene": 3, "Bale": 13, "Assella": 15},
    "Dollo": {"Gode": 17, "Mogadisho": 22},
    "Fanti Rasu": {"Awash": 7, "Kilbet Rasu": 6},
    "Finote Selam": {"Debre Markos": 3, "Bahir Dar": 6, "Injibara": 2},
    "Gambela": {"Gore": 5, "Dembi Dollo": 4},
    "Gimbi": {"Nekemte": 4, "Assosa": 8, "Dembi Dollo": 6},
    "Goba": {"Bale": 18, "Sof Oumer": 6},
    "Gode": {"Kebri Dehar": 5, "Dollo": 17, "Sof Oumer": 11},
    "Gondar": {"Debre Tabor": 6, "Azezo": 1, "Humera": 9, "Debark": 4},
    "Gore": {"Tepi": 9, "Gambela": 5, "Bedelle": 6},
    "Harar": {"Dire Dawa": 4, "Babile": 2},
    "Hawassa": {"Shashamene": 1, "Dilla": 3},
    "Hossana": {"Worabe": 2, "Wolaita Sodo": 4, "Shashamene": 7},
    "Humera": {"Shire": 8, "Gondar": 9, "Kartum": 21},
    "Injibara": {"Bahir Dar": 4, "Finote Selam": 2},
    "Jijiga": {"Babile": 3, "Dega Habur": 5},
    "Jimma": {"Wolkite": 8, "Bonga": 4, "Bedelle": 7},
    "Kartum": {"Humera": 21, "Metema": 19},
    "Kebri Dehar": {"Dega Habur": 6, "Gode": 5, "Werder": 6},
    "Kemise": {"Debre Sina": 6, "Dessia (Dessie)": 4},
    "Kilbet Rasu": {"Fanti Rasu": 6},
    "Konso": {"Arba Minch": 4, "Yabello": 3},
    "Lalibela": {"Woldia": 7, "Debre Tabor": 8, "Sekota": 6},
    "Liben": {"Moyale": 11},
    "Matahara": {"Adama": 3, "Awash": 1},
    "Mekelle": {"Woldia": 12, "Adigrat": 4, "Adwa": 7, "Sekota": 9, "Alamata": 5},
    "Metema": {"Azezo": 7, "Bahir Dar": 7, "Kartum": 19},
    "Mogadisho": {"Dollo": 22},
    "Moyale": {"Yabello": 6, "Liben": 11},
    "Nekemte": {"Ambo": 9, "Gimbi": 4, "Bedelle": 9},
    "Sekota": {"Lalibela": 6, "Mekelle": 9, "Alamata": 6},
    "Shashamene": {"Batu": 3, "Hawassa": 1, "Dodolla": 3, "Hossana": 7},
    "Shire": {"Axum": 2, "Humera": 8, "Adwa": 8, "Debark": 12},
    "Sof Oumer": {"Bale": 23, "Goba": 6, "Gode": 11},
    "Tepi": {"Gore": 9, "Bonga": 8},
    "Werder": {"Kebri Dehar": 6},
    "Woldia": {"Dessia (Dessie)": 6, "Mekelle": 12, "Lalibela": 7, "Alamata": 3},
    "Wolkite": {"Ambo": 6, "Worabe": 5, "Jimma": 8},
    "Wolaita Sodo": {"Hossana": 4, "Arba Minch": 4},
    "Worabe": {"Wolkite": 5, "Buta Jirra": 2, "Hossana": 2},
    "Yabello": {"Bule Hora": 3, "Konso": 3, "Moyale": 6}
    # Continue adding costs for all cities in Figure 2...
}

import heapq

def uniform_cost_search(graph, start, goal):
    # Priority Queue stores (cumulative_cost, current_node, path)
    priority_queue = [(0, start, [start])]
    visited = {} # Stores the minimum cost to reach a node

    while priority_queue:
        (cost, current_node, path) = heapq.heappop(priority_queue)

        if current_node == goal:
            return path, cost

        if current_node not in visited or cost < visited[current_node]:
            visited[current_node] = cost

            for neighbor, weight in graph.get(current_node, {}).items():
                new_cost = cost + weight
                new_path = list(path)
                new_path.append(neighbor)
                heapq.heappush(priority_queue, (new_cost, neighbor, new_path))

    return None, float('inf')

# Test Task 2.2
path, total_cost = uniform_cost_search(ethiopia_weighted_graph, "Addis Ababa", "Lalibela")
print(f"UCS Path to Lalibela: {path} \nTotal Distance: {total_cost}")
# Out:
# UCS Path to Lalibela: ['Addis Ababa', 'Debre Birhan', 'Debre Sina', 'Kemise', 'Dessia (Dessie)', 'Woldia', 'Lalibela']
# Total Distance: 30
